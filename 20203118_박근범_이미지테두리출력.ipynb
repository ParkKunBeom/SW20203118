# %% [markdown]
# # CV2 라이브러리를 이용해서 **이미지의 테두리**만 추출하는 코드
# ## 20203118 박근범
# ---
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
# import cv2
# from google.colab.patches import cv2_imshow
# import numpy as np
# ```
# drive 모듈을 이용하여 드라이브 마운트
# ```
# image_path="/content/drive/MyDrive/aaa.jpg"
# image=cv2.imread(image_path)
# cv2_imshow(image)
# ```
# image_path에 이미지 경로를 입력하고 image에 해당 이미지 대입 후, cv_imshow()를 통해 이미지 출력
# ```
# blur=cv2.GaussianBlur(image, ksize=(5,5), sigmaX=0)
# ret, thresh1=cv2.threshold(blur,127,255, cv2.THRESH_BINARY)
# ```
# 이미지에서 원하는 부분(고래)만 가져오기 위해 가우시안 블러 사용
#
# 블러는 이미지를 부드럽게 하기 때문에 원하지 않는 부분을 부드럽게 하여 해당 경계를 찾지 못하게 하기 위함
#
# 블러 처리를 심하게 하면 찾고자 하는 대상을 찾지 못하고, 야갛게 하면 배경의 외곽도 포함되므로 ksize를 적당히 조절
# ```
# edged = cv2.Canny(image,10,250)
# cv2_imshow(edged)
# ```
# cv2.Canny()를 이용하여 테두리(외각)을 찾아 낸뒤 출력

# %%
from google.colab import drive
drive.mount('/content/drive')
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image_path="/content/drive/MyDrive/aaa.jpg"
image=cv2.imread(image_path)
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=483x274>

# %%
blur=cv2.GaussianBlur(image, ksize=(5,5), sigmaX=0)
ret, thresh1=cv2.threshold(blur,127,255, cv2.THRESH_BINARY)
edged = cv2.Canny(image,10,250)
cv2_imshow(edged)
# Out:
# <PIL.Image.Image image mode=L size=483x274>
